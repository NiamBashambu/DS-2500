# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import (
    f1_score,
    accuracy_score,
    recall_score,
    precision_score,
    confusion_matrix,
    make_scorer,
)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)


df = pd.read_csv("/Users/niambashambu/Desktop/DS 2500/CSV Student Loan Classwork/2016_balances_borrowers.csv")
# Out:
#    Table 2. average student debt balance per borrowers by state/area  \
# 0            among borrowers with outstanding balance
# 1   Use "FRBNY Consumer Credit Panel / Equifax" fo...
# 2   Notes:\rThis table was created from a 5% repre...
# 3                                                 NaN
# 4                                          state/area
# 5                                              Alaska
# 6                                             Alabama
# 7                                            Arkansas
# 8                                             Arizona
# 9                                          California
# 10                                           Colorado
# 11                                        Connecticut
# 12                               District of Columbia
# 13                                           Delaware
# 14                                            Florida
# 15                                            Georgia
# 16                                             Hawaii
# 17                                               Iowa
# 18                                              Idaho
# 19                                           Illinois
# 20                                            Indiana
# 21                                             Kansas
# 22                                           Kentucky
# 23                                          Louisiana
# 24                                      Massachusetts
# 25                                           Maryland
# 26                                              Maine
# 27                                           Michigan
# 28                                          Minnesota
# 29                                           Missouri
# 30                                        Mississippi
# 31                                            Montana
# 32                                     North Carolina
# 33                                       North Dakota
# 34                                           Nebraska
# 35                                      New Hampshire
# 36                                         New Jersey
# 37                                         New Mexico
# 38                                             Nevada
# 39                                           New York
# 40                                               Ohio
# 41                                           Oklahoma
# 42                                             Oregon
# 43                                       Pennsylvania
# 44                                        Puerto Rico
# 45                                       Rhode Island
# 46                                     South Carolina
# 47                                       South Dakota
# 48                                          Tennessee
# 49                                              Texas
# 50                                               Utah
# 51                                           Virginia
# 52                                            Vermont
# 53                                         Washington
# 54                                          Wisconsin
# 55                                      West Virginia
# 56                                            Wyoming
#
#        Unnamed: 1     Unnamed: 2
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4   num borrowers  total balance
# 5          79,500         $2,233
# 6         601,700        $19,182
# 7         368,100        $10,320
# 8         860,500        $26,877
# 9       4,208,700       $134,125
# 10        836,600        $26,430
# 11        553,300        $17,230
# 12        135,100         $6,608
# 13        126,700         $4,027
# 14      2,590,000        $86,172
# 15      1,568,900        $56,462
# 16        136,200         $3,990
# 17        511,700        $13,033
# 18        222,500         $6,425
# 19      1,821,500        $58,585
# 20      1,009,100        $28,241
# 21        423,500        $11,737
# 22        598,800        $16,960
# 23        613,400        $18,969
# 24      1,090,600        $33,285
# 25        891,000        $32,572
# 26        217,900         $6,045
# 27      1,546,900        $47,314
# 28        980,400        $27,110
# 29        890,000        $26,737
# 30        420,200        $13,300
# 31        128,800         $3,798
# 32      1,280,400        $41,247
# 33        120,700         $2,991
# 34        278,800         $7,532
# 35        240,400         $7,065
# 36      1,359,100        $43,106
# 37        238,500         $6,742
# 38        317,800         $9,767
# 39      2,772,300        $90,648
# 40      1,959,600        $58,437
# 41        479,600        $13,212
# 42        588,300        $18,886
# 43      2,154,300        $64,620
# 44        308,400         $7,045
# 45        160,700         $4,501
# 46        711,500        $23,324
# 47        138,700         $3,474
# 48        846,200        $26,528
# 49      3,483,200       $101,354
# 50        328,600         $9,315
# 51      1,165,000        $39,463
# 52         98,900         $2,919
# 53        872,100        $26,395
# 54        841,800        $22,591
# 55        234,200         $6,367
# 56         60,400         $1,483

# %%
df.shape
# Out:
# (57, 3)

# %%
df.head(20)
# Out:
#    Table 2. average student debt balance per borrowers by state/area  \
# 0            among borrowers with outstanding balance
# 1   Use "FRBNY Consumer Credit Panel / Equifax" fo...
# 2   Notes:\rThis table was created from a 5% repre...
# 3                                                 NaN
# 4                                          state/area
# 5                                              Alaska
# 6                                             Alabama
# 7                                            Arkansas
# 8                                             Arizona
# 9                                          California
# 10                                           Colorado
# 11                                        Connecticut
# 12                               District of Columbia
# 13                                           Delaware
# 14                                            Florida
# 15                                            Georgia
# 16                                             Hawaii
# 17                                               Iowa
# 18                                              Idaho
# 19                                           Illinois
#
#        Unnamed: 1     Unnamed: 2
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4   num borrowers  total balance
# 5          79,500         $2,233
# 6         601,700        $19,182
# 7         368,100        $10,320
# 8         860,500        $26,877
# 9       4,208,700       $134,125
# 10        836,600        $26,430
# 11        553,300        $17,230
# 12        135,100         $6,608
# 13        126,700         $4,027
# 14      2,590,000        $86,172
# 15      1,568,900        $56,462
# 16        136,200         $3,990
# 17        511,700        $13,033
# 18        222,500         $6,425
# 19      1,821,500        $58,585

# %%
df.count()
# Out:
# Table 2. average student debt balance per borrowers by state/area    56
# Unnamed: 1                                                           53
# Unnamed: 2                                                           53
# dtype: int64
